# %% [markdown]
# ## IMPORTS

# %%
# Data manipulation
import numpy as np
import pandas as pd

# Data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# TensorFlow and Keras
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, BatchNormalization
from keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau



# Scikit-learn
from sklearn.model_selection import train_test_split
from sklearn.utils import resample, class_weight
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler

# Other
import os
import shutil
import cv2  # For image processing
import random
from google.colab import userdata

# %%
# Access the secret key
secret_value = userdata.get('shisiajoy')

# %%
pip install pillow
# Out:
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (11.0.0)

# %%
# Install Kaggle API if not already installed
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (1.6.17)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi>=2023.7.22 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2024.8.30)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle) (4.66.6)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.2.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle) (6.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.10)

# %%
# !kaggle datasets download -d gauravduttakiit/rsna-screening-mammography-breast-cancer-detection
# Out:
# Dataset URL: https://www.kaggle.com/datasets/gauravduttakiit/rsna-screening-mammography-breast-cancer-detection
# License(s): CC0-1.0
# Downloading rsna-screening-mammography-breast-cancer-detection.zip to /content
# 100% 0.98G/0.98G [00:13<00:00, 98.8MB/s]
# 100% 0.98G/0.98G [00:13<00:00, 80.2MB/s]

# %%
# !unzip rsna-screening-mammography-breast-cancer-detection.zip -d /content/rsna_mammography_dataset
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/rsna_mammography_dataset/output/train/63617_1917877119.png
#   inflating: /content/rsna_mammography_dataset/output/train/63617_887426674.png
#   inflating: /content/rsna_mammography_dataset/output/train/63623_1186739164.png
#   inflating: /content/rsna_mammography_dataset/output/train/63623_1657034655.png
#   inflating: /content/rsna_mammography_dataset/output/train/63623_335778602.png
#   inflating: /content/rsna_mammography_dataset/output/train/63623_625719002.png
#   inflating: /content/rsna_mammography_dataset/output/train/63626_1154699412.png
#   inflating: /content/rsna_mammography_dataset/output/train/63626_549972940.png
#   inflating: /content/rsna_mammography_dataset/output/train/63626_599167493.png
#   inflating: /content/rsna_mammography_dataset/output/train/63626_939566995.png
#   inflating: /content/rsna_mammography_dataset/output/train/63627_1214214469.png
#   inflating: /content/rsna_mammography_dataset/output/train/63627_191294190.png
#   inflating: /content/rsna_mammography_dataset/output/train/63627_669536679.png
#   inflating: /content/rsna_mammography_dataset/output/train/63627_92618283.png
#   inflating: /content/rsna_mammography_dataset/output/train/63628_1068923688.png
#   inflating: /content/rsna_mammography_dataset/output/train/63628_1252453513.png
#   inflating: /content/rsna_mammography_dataset/output/train/63628_1987323650.png
#   inflating: /content/rsna_mammography_dataset/output/train/63628_882454541.png
#   inflating: /content/rsna_mammography_dataset/output/train/63630_1460649623.png
#   inflating: /content/rsna_mammography_dataset/output/train/63630_201599249.png
#   inflating: /content/rsna_mammography_dataset/output/train/63630_2076739376.png
#   inflating: /content/rsna_mammography_dataset/output/train/63630_459372349.png
#   inflating: /content/rsna_mammography_dataset/output/train/63636_1357547457.png
#   inflating: /content/rsna_mammography_dataset/output/train/63636_1436427381.png
#   inflating: /content/rsna_mammography_dataset/output/train/63636_2062211498.png
#   inflating: /content/rsna_mammography_dataset/output/train/63636_336945978.png
#   inflating: /content/rsna_mammography_dataset/output/train/63636_922288573.png
#   inflating: /content/rsna_mammography_dataset/output/train/63636_973884730.png
#   inflating: /content/rsna_mammography_dataset/output/train/63639_1192000553.png
#   inflating: /content/rsna_mammography_dataset/output/train/63639_1287573528.png
#   inflating: /content/rsna_mammography_dataset/output/train/63639_1485151913.png
#   inflating: /content/rsna_mammography_dataset/output/train/9955_1947380724.png
#   inflating: /content/rsna_mammography_dataset/output/train/9955_255391556.png
#   inflating: /content/rsna_mammography_dataset/output/train/9955_629099099.png
#   inflating: /content/rsna_mammography_dataset/output/train/9965_1229053771.png
#   inflating: /content/rsna_mammography_dataset/output/train/9965_1523807232.png
#   inflating: /content/rsna_mammography_dataset/output/train/9965_1990076391.png
#   inflating: /content/rsna_mammography_dataset/output/train/9965_69676487.png
#   inflating: /content/rsna_mammography_dataset/output/train/9967_1245697729.png
#   inflating: /content/rsna_mammography_dataset/output/train/9967_1260162631.png
#   inflating: /content/rsna_mammography_dataset/output/train/9967_155474390.png
#   inflating: /content/rsna_mammography_dataset/output/train/9967_244243187.png
#   inflating: /content/rsna_mammography_dataset/output/train/9968_2098937312.png
#   inflating: /content/rsna_mammography_dataset/output/train/9968_294168046.png
#   inflating: /content/rsna_mammography_dataset/output/train/9968_568005453.png
#   inflating: /content/rsna_mammography_dataset/output/train/9968_766198919.png
#   inflating: /content/rsna_mammography_dataset/output/train/9973_1345265157.png
#   inflating: /content/rsna_mammography_dataset/output/train/9973_1703611570.png
#   inflating: /content/rsna_mammography_dataset/output/train/9973_1729524723.png
#   inflating: /content/rsna_mammography_dataset/output/train/9973_655941939.png
#   inflating: /content/rsna_mammography_dataset/output/train/997_1487679918.png
#   inflating: /content/rsna_mammography_dataset/output/train/997_1775983513.png
#   inflating: /content/rsna_mammography_dataset/output/train/997_2129119612.png
#   inflating: /content/rsna_mammography_dataset/output/train/997_873425464.png
#   inflating: /content/rsna_mammography_dataset/output/train/9989_1078943060.png
#   inflating: /content/rsna_mammography_dataset/output/train/9989_398038886.png
#   inflating: /content/rsna_mammography_dataset/output/train/9989_439796429.png
#   inflating: /content/rsna_mammography_dataset/output/train/9989_63473691.png
#   inflating: /content/rsna_mammography_dataset/test.csv
#   inflating: /content/rsna_mammography_dataset/train.csv

# %%
# !ls /content/rsna_mammography_dataset
# Out:
# output	test.csv  train.csv

# %%
train_df = pd.read_csv("/content/rsna_mammography_dataset/train.csv")
test_df = pd.read_csv("/content/rsna_mammography_dataset/test.csv")

# %%
train_df.head()
# Out:
#    site_id  patient_id    image_id laterality view   age  implant  machine_id  \
# 0        2       10006   462822612          L   CC  61.0        0          29
# 1        2       10006  1459541791          L  MLO  61.0        0          29
# 2        2       10006  1864590858          R  MLO  61.0        0          29
# 3        2       10006  1874946579          R   CC  61.0        0          29
# 4        2       10011   220375232          L   CC  55.0        0          21
#
#   prediction_id  cancer
# 0       10006_L       0
# 1       10006_L       0
# 2       10006_R       0
# 3       10006_R       0
# 4       10011_L       0

# %%
test_df.head()
# Out:
#    site_id  patient_id    image_id laterality view  age  implant  machine_id  \
# 0        2       10008   736471439          L  MLO   81        0          21
# 1        2       10008  1591370361          L   CC   81        0          21
# 2        2       10008    68070693          R  MLO   81        0          21
# 3        2       10008   361203119          R   CC   81        0          21
#
#   prediction_id
# 0       10008_L
# 1       10008_L
# 2       10008_R
# 3       10008_R

# %% [markdown]
# ##EDA

# %% [markdown]
# - Age distribution

# %%
plt.figure(figsize=(8, 6))
sns.histplot(train_df['age'], bins=20, kde=True)
plt.title('Age Distribution of Patients')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# - Age vs Cancer

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x='cancer', y='age', data=train_df)
plt.title('Age vs. Cancer Diagnosis')
plt.xlabel('Cancer (0: No, 1: Yes)')
plt.ylabel('Age')
plt.xticks([0, 1], ['No Cancer', 'Cancer'])
plt.show()

# %% [markdown]
# - Cancer diagnosis by Laterality and view

# %%
plt.figure(figsize=(7, 5))
sns.countplot(data=train_df, x='laterality', hue='cancer')
plt.title('Cancer Diagnosis by Laterality')
plt.xlabel('Laterality')
plt.ylabel('Count')
plt.legend(title='Cancer', labels=['No Cancer', 'Cancer'])
plt.show()

plt.figure(figsize=(7, 5))
sns.countplot(data=train_df, x='view', hue='cancer')
plt.title('Cancer Diagnosis by View')
plt.xlabel('View')
plt.ylabel('Count')
plt.legend(title='Cancer', labels=['No Cancer', 'Cancer'])
plt.show()

# %% [markdown]
# - Cancer class distribution

# %%
# Plot class distribution
train_df['cancer'].value_counts().plot(kind='bar')
plt.title('Class Distribution in Training Data')
plt.xlabel('Cancer Presence (0 = No, 1 = Yes)')
plt.ylabel('Count')
plt.xticks(ticks=[0, 1], labels=['No Cancer', 'Cancer'], rotation=0)
plt.show()

# %% [markdown]
# ## SETTING UP DIRECTORIES

# %%
# Define paths
base_path = '/content/rsna_mammography_dataset/output/train'
cancer_path = os.path.join(base_path, 'cancer')
no_cancer_path = os.path.join(base_path, 'no_cancer')

# %%
# Base directory paths

base_path = '/content/rsna_mammography_dataset/output/train'
cancer_path = os.path.join(base_path, 'cancer')
no_cancer_path = os.path.join(base_path, 'no_cancer')

# %%
# Function to add path directory to the DataFrame
def add_path_directory(row):
    patient_id = row['patient_id']
    image_id = row['image_id']
    cancer_label = row['cancer']  # 1 = cancer, 0 = no cancer

    # Construct image filename
    image_filename = f"{patient_id}_{image_id}.png"

    # Add appropriate directory path
    if cancer_label == 1:
        return os.path.join(cancer_path, image_filename)
    else:
        return os.path.join(no_cancer_path, image_filename)

# Add 'path_directory' column
train_df['path_directory'] = train_df.apply(add_path_directory, axis=1)
print("Added 'path_directory' column to train_df.")
# Out:
# Added 'path_directory' column to train_df.

# %%
train_df.head()
# Out:
#    site_id  patient_id    image_id laterality view   age  implant  machine_id  \
# 0        2       10006   462822612          L   CC  61.0        0          29
# 1        2       10006  1459541791          L  MLO  61.0        0          29
# 2        2       10006  1864590858          R  MLO  61.0        0          29
# 3        2       10006  1874946579          R   CC  61.0        0          29
# 4        2       10011   220375232          L   CC  55.0        0          21
#
#   prediction_id  cancer                                     path_directory
# 0       10006_L       0  /content/rsna_mammography_dataset/output/train...
# 1       10006_L       0  /content/rsna_mammography_dataset/output/train...
# 2       10006_R       0  /content/rsna_mammography_dataset/output/train...
# 3       10006_R       0  /content/rsna_mammography_dataset/output/train...
# 4       10011_L       0  /content/rsna_mammography_dataset/output/train...

# %% [markdown]
# Move images to directory

# %%
# Create the cancer and no_cancer directories
os.makedirs(cancer_path, exist_ok=True)
os.makedirs(no_cancer_path, exist_ok=True)

# Function to move images to respective directories
def organize_images(row):
    patient_id = row['patient_id']
    image_id = row['image_id']
    cancer_label = row['cancer']  # Assuming 1 indicates cancer, 0 indicates no cancer

    image_filename = f"{patient_id}_{image_id}.png"
    image_path = os.path.join(base_path, image_filename)

    # Check if the image exists
    if os.path.exists(image_path):
        if cancer_label == 1:
            shutil.move(image_path, os.path.join(cancer_path, image_filename))
        else:
            shutil.move(image_path, os.path.join(no_cancer_path, image_filename))
    else:
        print(f"Image {image_filename} not found in {base_path}.")

# Apply the function to organize images
train_df.apply(organize_images, axis=1)
print("Images have been organized into 'cancer' and 'no_cancer' folders.")
# Out:
# Images have been organized into 'cancer' and 'no_cancer' folders.

# %%
# List all files in the source directory
actual_files = os.listdir('/content/rsna_mammography_dataset/output/train/no_cancer')
print(f"Number of files in 'no_cancer' directory: {len(actual_files)}")
# Out:
# Number of files in 'no_cancer' directory: 53548

# %%
# Check for mismatched extensions
expected_extensions = {'.png', '.jpg', '.jpeg'}
train_df['file_extension'] = train_df['path_directory'].apply(lambda x: os.path.splitext(x)[-1])
invalid_extensions = train_df[~train_df['file_extension'].isin(expected_extensions)]
print(f"Number of invalid extensions: {len(invalid_extensions)}")
print(invalid_extensions.head())
# Out:
# Number of invalid extensions: 0
# Empty DataFrame
# Columns: [site_id, patient_id, image_id, laterality, view, age, implant, machine_id, prediction_id, cancer, path_directory, file_extension]
# Index: []

# %%
# Function to load a subset of images from the 'no_cancer' folder
def load_images_from_folder(folder, img_size=(128, 128), sample_size=None):
    images = []
    filenames = os.listdir(folder)

    # If a sample size is provided, randomly select images
    if sample_size:
        filenames = random.sample(filenames, sample_size)

    for filename in filenames:
        img_path = os.path.join(folder, filename)
        img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
        if img is not None:
            img = cv2.resize(img, img_size)
            images.append(img)
    return np.array(images)

# Load only a subset of no cancer images
subset_size = 30050
no_cancer_images = load_images_from_folder(no_cancer_path, sample_size=subset_size)

# %% [markdown]
# ## META DATA PREPROCESSING

# %%
# Preprocess metadata
metadata = train_df[['laterality', 'view', 'age', 'implant']]

# One-hot encode categorical data
encoder = OneHotEncoder()
categorical_metadata = encoder.fit_transform(metadata[['laterality', 'view']]).toarray()

# Normalize numerical data
scaler = MinMaxScaler()
numerical_metadata = scaler.fit_transform(metadata[['age', 'implant']])

# Combine preprocessed metadata
processed_metadata = np.hstack((categorical_metadata, numerical_metadata))

# %% [markdown]
# ## IMAGES PREPROCESSING

# %%
# Normalize and reshape the images
no_cancer_images = no_cancer_images.astype('float32') / 255.0
no_cancer_images = np.expand_dims(no_cancer_images, axis=-1)

# %% [markdown]
# ## TRAIN VALIDATION SPLIT

# %%
#  Split into train and test sets
train_images, test_images = train_test_split(no_cancer_images, test_size=0.2, random_state=42)

#  Split the train set into training and validation sets
train_images, val_images = train_test_split(train_images, test_size=0.25, random_state=42)  # 0.25 * 0.8 = 0.2

# %% [markdown]
# ## MODEL CREATION

# %%
# Define the autoencoder model
def build_autoencoder(input_shape):
    # Encoder
    encoder_input = layers.Input(shape=input_shape)
    x = layers.Conv2D(32, (3, 3), padding='same')(encoder_input)
    x = layers.BatchNormalization()(x)  # Batch Normalization
    x = layers.Activation('relu')(x)
    x = layers.MaxPooling2D((2, 2), padding='same')(x)

    x = layers.Conv2D(64, (3, 3), padding='same')(x)
    x = layers.BatchNormalization()(x)  # Batch Normalization
    x = layers.Activation('relu')(x)
    x = layers.MaxPooling2D((2, 2), padding='same')(x)

    # Latent space with tanh activation and Batch Normalization
    latent = layers.Conv2D(64, (3, 3), padding='same')(x)
    latent = layers.BatchNormalization()(latent)  # Batch Normalization
    latent = layers.Activation('tanh')(latent)

    # Decoder
    x = layers.Conv2D(64, (3, 3), padding='same')(latent)
    x = layers.BatchNormalization()(x)  # Batch Normalization
    x = layers.Activation('relu')(x)
    x = layers.UpSampling2D((2, 2))(x)

    x = layers.Conv2D(32, (3, 3), padding='same')(x)
    x = layers.BatchNormalization()(x)  # Batch Normalization
    x = layers.Activation('relu')(x)
    x = layers.UpSampling2D((2, 2))(x)

    # Final reconstruction layer with sigmoid activation for grayscale output
    decoder_output = layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

    # Create the autoencoder model
    autoencoder = models.Model(encoder_input, decoder_output)
    return autoencoder

# Set input shape for the model (image size 128x128, with 1 channel for grayscale)
input_shape = (128, 128, 1)
autoencoder = build_autoencoder(input_shape)

# Compile the autoencoder with mean_squared_error loss
autoencoder.compile(optimizer='adam', loss='mean_squared_error')

# Check the model summary to ensure the architecture
autoencoder.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 128, 128, 1)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 128, 128, 32)        │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 128, 128, 32)        │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation (Activation)              │ (None, 128, 128, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 64, 64, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 64, 64, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 64, 64, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_1 (Activation)            │ (None, 64, 64, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 32, 32, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 32, 32, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 32, 32, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_2 (Activation)            │ (None, 32, 32, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 32, 32, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 32, 32, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_3 (Activation)            │ (None, 32, 32, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ up_sampling2d (UpSampling2D)         │ (None, 64, 64, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 64, 64, 32)          │          18,464 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 64, 64, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_4 (Activation)            │ (None, 64, 64, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ up_sampling2d_1 (UpSampling2D)       │ (None, 128, 128, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 128, 128, 1)         │             289 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 112,449 (439.25 KB)
#  Trainable params: 111,937 (437.25 KB)
#  Non-trainable params: 512 (2.00 KB)

# %%
# Define callbacks for early stopping and learning rate reduction
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6)

# %% [markdown]
# ## MODEL TRAINING

# %%
# Train the autoencoder
history = autoencoder.fit(train_images, train_images,
                          epochs=50,
                          batch_size=32,
                          validation_data=(val_images, val_images),
                          callbacks=[early_stopping, lr_scheduler])
# Out:
# Epoch 1/50
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 34s 42ms/step - loss: 0.0086 - val_loss: 0.0047 - learning_rate: 0.0010
# Epoch 2/50
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 28s 32ms/step - loss: 0.0017 - val_loss: 0.0013 - learning_rate: 0.0010
# Epoch 3/50
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 19s 29ms/step - loss: 0.0018 - val_loss: 0.0011 - learning_rate: 0.0010
# Epoch 4/50
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - loss: 0.0013 - val_loss: 9.4862e-04 - learning_rate: 0.0010
# Epoch 5/50
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 22s 32ms/step - loss: 0.0012 - val_loss: 9.8475e-04 - learning_rate: 0.0010
# Epoch 6/50
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 18s 32ms/step - loss: 0.0011 - val_loss: 0.0014 - learning_rate: 0.0010
# Epoch 7/50
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 19s 30ms/step - loss: 0.0011 - val_loss: 8.6731e-04 - learning_rate: 0.0010
# Epoch 8/50
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 18s 32ms/step - loss: 8.4470e-04 - val_loss: 7.5675e-04 - learning_rate: 5.0000e-04
# Epoch 9/50
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 19s 29ms/step - loss: 9.9347e-04 - val_loss: 7.6727e-04 - learning_rate: 5.0000e-04
# Epoch 10/50
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 20s 29ms/step - loss: 0.0011 - val_loss: 8.3115e-04 - learning_rate: 5.0000e-04
# Epoch 11/50
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 16s 29ms/step - loss: 0.0011 - val_loss: 7.5088e-04 - learning_rate: 5.0000e-04
# Epoch 12/50
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 16s 29ms/step - loss: 7.3679e-04 - val_loss: 7.5763e-04 - learning_rate: 2.5000e-04
# Epoch 13/50
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 16s 29ms/step - loss: 7.2252e-04 - val_loss: 6.6323e-04 - learning_rate: 2.5000e-04
# Epoch 14/50
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 16s 29ms/step - loss: 7.8900e-04 - val_loss: 6.5281e-04 - learning_rate: 2.5000e-04
# Epoch 15/50
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 16s 29ms/step - loss: 7.0880e-04 - val_loss: 6.4007e-04 - learning_rate: 2.5000e-04
# Epoch 16/50
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - loss: 6.6263e-04 - val_loss: 6.2482e-04 - learning_rate: 2.5000e-04
# Epoch 17/50
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 16s 29ms/step - loss: 6.7751e-04 - val_loss: 6.1308e-04 - learning_rate: 2.5000e-04
# Epoch 18/50
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 18s 31ms/step - loss: 6.3267e-04 - val_loss: 5.9793e-04 - learning_rate: 1.2500e-04
# Epoch 19/50
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 16s 29ms/step - loss: 6.1810e-04 - val_loss: 6.1830e-04 - learning_rate: 1.2500e-04
# Epoch 20/50
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 17s 29ms/step - loss: 6.0989e-04 - val_loss: 5.8227e-04 - learning_rate: 1.2500e-04
# Epoch 21/50
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 17s 29ms/step - loss: 6.2496e-04 - val_loss: 5.7332e-04 - learning_rate: 6.2500e-05
# Epoch 22/50
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 17s 29ms/step - loss: 5.9669e-04 - val_loss: 5.7131e-04 - learning_rate: 6.2500e-05
# Epoch 23/50
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 17s 29ms/step - loss: 6.0421e-04 - val_loss: 5.6561e-04 - learning_rate: 6.2500e-05
# Epoch 24/50
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 5.8283e-04 - val_loss: 5.7805e-04 - learning_rate: 3.1250e-05
# Epoch 25/50
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 20s 29ms/step - loss: 5.8185e-04 - val_loss: 5.7406e-04 - learning_rate: 3.1250e-05
# Epoch 26/50
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 5.9418e-04 - val_loss: 5.6515e-04 - learning_rate: 3.1250e-05
# Epoch 27/50
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 17s 29ms/step - loss: 5.7800e-04 - val_loss: 5.5767e-04 - learning_rate: 1.5625e-05
# Epoch 28/50
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 18s 32ms/step - loss: 6.0471e-04 - val_loss: 5.5717e-04 - learning_rate: 1.5625e-05
# Epoch 29/50
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 19s 29ms/step - loss: 5.8036e-04 - val_loss: 5.6011e-04 - learning_rate: 1.5625e-05
# Epoch 30/50
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 17s 29ms/step - loss: 5.7420e-04 - val_loss: 5.5455e-04 - learning_rate: 7.8125e-06
# Epoch 31/50
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 22s 32ms/step - loss: 5.6588e-04 - val_loss: 5.5345e-04 - learning_rate: 7.8125e-06
# Epoch 32/50
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 16s 29ms/step - loss: 5.7386e-04 - val_loss: 5.5656e-04 - learning_rate: 7.8125e-06
# Epoch 33/50
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 20s 29ms/step - loss: 5.7839e-04 - val_loss: 5.5306e-04 - learning_rate: 3.9063e-06
# Epoch 34/50
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 16s 29ms/step - loss: 5.7279e-04 - val_loss: 5.5253e-04 - learning_rate: 3.9063e-06
# Epoch 35/50
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 18s 31ms/step - loss: 5.8308e-04 - val_loss: 5.5215e-04 - learning_rate: 3.9063e-06
# Epoch 36/50
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 16s 29ms/step - loss: 5.6858e-04 - val_loss: 5.5187e-04 - learning_rate: 3.9063e-06
# Epoch 37/50
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 16s 29ms/step - loss: 5.6751e-04 - val_loss: 5.5146e-04 - learning_rate: 3.9063e-06
# Epoch 38/50
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 5.6760e-04 - val_loss: 5.5104e-04 - learning_rate: 1.9531e-06
# Epoch 39/50
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 16s 29ms/step - loss: 5.6880e-04 - val_loss: 5.5295e-04 - learning_rate: 1.9531e-06
# Epoch 40/50
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 5.6678e-04 - val_loss: 5.5117e-04 - learning_rate: 1.9531e-06
# Epoch 41/50
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 17s 29ms/step - loss: 5.7132e-04 - val_loss: 5.5249e-04 - learning_rate: 1.0000e-06
# Epoch 42/50
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 22s 32ms/step - loss: 5.7388e-04 - val_loss: 5.5040e-04 - learning_rate: 1.0000e-06
# Epoch 43/50
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 19s 29ms/step - loss: 5.6553e-04 - val_loss: 5.5022e-04 - learning_rate: 1.0000e-06
# Epoch 44/50
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 20s 29ms/step - loss: 5.9160e-04 - val_loss: 5.5125e-04 - learning_rate: 1.0000e-06
# Epoch 45/50
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 18s 31ms/step - loss: 5.7213e-04 - val_loss: 5.5101e-04 - learning_rate: 1.0000e-06
# Epoch 46/50
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 17s 29ms/step - loss: 5.6463e-04 - val_loss: 5.5029e-04 - learning_rate: 1.0000e-06
# Epoch 47/50
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 16s 29ms/step - loss: 5.6821e-04 - val_loss: 5.4998e-04 - learning_rate: 1.0000e-06
# Epoch 48/50
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 5.6769e-04 - val_loss: 5.5012e-04 - learning_rate: 1.0000e-06
# Epoch 49/50
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 19s 29ms/step - loss: 5.6430e-04 - val_loss: 5.5016e-04 - learning_rate: 1.0000e-06
# Epoch 50/50
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 22s 32ms/step - loss: 5.6517e-04 - val_loss: 5.5118e-04 - learning_rate: 1.0000e-06

# %% [markdown]
# ## MODEL EVALUATION

# %% [markdown]
# - Visualization of reconstructed images

# %%
# Get a batch of validation images
val_images_batch = val_images[:10]
reconstructed_images = autoencoder.predict(val_images_batch)

# Plot original and reconstructed images
plt.figure(figsize=(20, 4))
for i in range(10):
    # Original images
    ax = plt.subplot(2, 10, i + 1)
    plt.imshow(val_images_batch[i].reshape(128, 128), cmap='gray')
    plt.title("Original")
    plt.axis("off")

    # Reconstructed images
    ax = plt.subplot(2, 10, i + 11)
    plt.imshow(reconstructed_images[i].reshape(128, 128), cmap='gray')
    plt.title("Reconstructed")
    plt.axis("off")
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 901ms/step

# %% [markdown]
# ## EVALUATION ON TEST SET

# %%
# Evaluate on the test set
test_images_reconstructed = autoencoder.predict(test_images)

# Calculate the reconstruction loss (mean squared error) for each image
reconstruction_loss = np.mean(np.power(test_images - test_images_reconstructed, 2), axis=(1, 2))

# Analyze reconstruction loss distribution
plt.hist(reconstruction_loss, bins=50)
plt.xlabel('Reconstruction Loss')
plt.ylabel('Frequency')
plt.title('Reconstruction Loss Distribution on Test Set')
plt.show()
# Out:
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step

# %%
# Calculate Reconstruction Errors
reconstructed_images = autoencoder.predict(test_images)  # Test dataset
reconstruction_errors = np.mean((test_images - reconstructed_images) ** 2, axis=(1, 2))  # Mean Squared Error per image

# Visualize Reconstruction Errors
plt.figure(figsize=(8, 6))
plt.hist(reconstruction_errors, bins=50, color='blue', alpha=0.7, label='Reconstruction Errors')
plt.axvline(x=np.mean(reconstruction_errors) + 2 * np.std(reconstruction_errors), color='red', linestyle='--', label='Threshold')
plt.xlabel('Reconstruction Error')
plt.ylabel('Number of Images')
plt.title('Distribution of Reconstruction Errors on Test set')
plt.legend()
plt.show()
# Out:
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step

# %%
# Set a Threshold
threshold = np.mean(reconstruction_errors) + 2 * np.std(reconstruction_errors)

# Classify Images
anomalies = reconstruction_errors > threshold

# Count Anomalies
print(f"Number of Anomalies Detected: {np.sum(anomalies)}")
# Out:
# Number of Anomalies Detected: 192

# %%
def compute_reconstruction_error(autoencoder, images):
    reconstructions = autoencoder.predict(images)
    errors = np.mean((images - reconstructions) ** 2, axis=(1, 2, 3))
    return errors

# Load cancer images for testing
cancer_images = load_images_from_folder(cancer_path, img_size=(128, 128))
cancer_images = cancer_images / 255.0  # Normalize
cancer_images = cancer_images.reshape(-1, 128, 128, 1)

# Compute reconstruction errors
no_cancer_errors = compute_reconstruction_error(autoencoder, no_cancer_images)
cancer_errors = compute_reconstruction_error(autoencoder, cancer_images)
# Out:
# 940/940 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step

# %%
# Reconstruct the test images
reconstructed_images = autoencoder.predict(test_images)

# Calculate the reconstruction loss
reconstruction_losses = np.mean(np.square(test_images - reconstructed_images), axis=(1, 2))  # Mean squared error across the image dimensions

# proceed to calculate mean and std
mean_loss = np.mean(reconstruction_losses)
std_loss = np.std(reconstruction_losses)

# Set threshold
threshold = mean_loss + 0.1 * std_loss

print(f'Mean Loss: {mean_loss:.6f}, Standard Deviation: {std_loss:.6f}, Threshold: {threshold:.6f}')
# Out:
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# Mean Loss: 0.000683, Standard Deviation: 0.000433, Threshold: 0.000727

# %% [markdown]
# ## TEST ON LABLED DATA

# %%
# Load and preprocess the single cancer image
image_path = '/content/rsna_mammography_dataset/output/test/10008_68070693.png'  # Path to your image
image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)  # Read as grayscale
image = cv2.resize(image, (128, 128))  # Resize to match input shape
image = image.astype('float32') / 255.0  # Normalize to [0, 1]
image = np.expand_dims(image, axis=-1)  # Add channel dimension
image = np.expand_dims(image, axis=0)  # Add batch dimension

# Reconstruct the image using the autoencoder
reconstructed_image = autoencoder.predict(image)

# Calculate the reconstruction loss
reconstruction_loss = np.mean(np.square(image - reconstructed_image))

# Classify based on the threshold
is_anomalous = reconstruction_loss > threshold

# Output results
print(f'Reconstruction Loss: {reconstruction_loss:.6f}')
print(f'Anomalous: {is_anomalous}')

# visualize the original and reconstructed images

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.title('Original Image')
plt.imshow(image.squeeze(), cmap='gray')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.title('Reconstructed Image')
plt.imshow(reconstructed_image.squeeze(), cmap='gray')
plt.axis('off')

plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Reconstruction Loss: 0.000811
# Anomalous: True

# %% [markdown]
# ## SAVE MODEL AND THRESHOLD

# %%
 # Save the autoencoder in Keras format
autoencoder.save('autoencoder_model.keras')

# %%
from google.colab import files
files.download('autoencoder_model.keras')

# %%
import json

# Save the threshold value to a JSON file
threshold_value = 0.000727
with open('threshold.json', 'w') as json_file:
    json.dump({'threshold': threshold_value}, json_file)
